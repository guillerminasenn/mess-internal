# %% [markdown]
# # JCGS Notebook Track
#
# This folder contains the active notebooks for the additional numerics.
#
# Main notebooks:
# - `01_solute_transport_convergence_pilot.ipynb`: full d=40 convergence comparisons (mPCN, pCN, EP-pCN, MESS, ESS, EP-ESS).
# - `03_logistic_regression_likelihood_experiments.ipynb`: Section 1 logistic-likelihood experiments and plots.
#
# Support notebook:
# - `02_d10_config_parity_check.ipynb`: d=10 config parity checks before mixing reused mPCN with MESS outputs.
#
# Notes:
# - These notebooks print warnings when expected local chains are not found.
# - Missing-chain warnings are also saved as JSON in each notebook report directory.

# %%
from pathlib import Path

here = Path.cwd()
print('Notebook cwd:', here)
print('JCGS notebook files:')
for path in sorted(here.glob('*.ipynb')):
    print('-', path.name)
# Out:
# Notebook cwd: /Users/guillers/Documents/GitHub/mcmc/mess-internal/notebooks/jcgs-notebooks
# Folder contents:
# - 00_jcgs_notebooks_index.ipynb
# - 01_solute_transport_convergence_pilot.ipynb
# - 02_d10_config_parity_check.ipynb
