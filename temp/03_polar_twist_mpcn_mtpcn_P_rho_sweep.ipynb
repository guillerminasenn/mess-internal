# %% [markdown]
# # Polar twist mPCN/mTPCN P vs rho sweep
#
# Run mPCN and mTPCN across $P$ and $\rho$ for the polar-twist posterior, using cached chains and metrics.
#
# Generate ESS/MSJD sweeps plots included in the paper.

# %% [markdown]
# ## Notebook summary (auto)
# - Defines a 2D polar-twist forward map and Gaussian likelihood.
# - Generates synthetic observations from a prior sample with additive noise.
# - Sweeps mPCN and mTPCN over $\rho$ and $P$, plus pCN baselines, using cached chains.
# - Loads metrics from disk (or recomputes metrics only) without rerunning chains.
# - Produces diagnostics/plots: traceplots, histograms, ESS/MSJD curves, rejection rates, and edge-$\rho$ zooms.

# %%
import os
import sys
from pathlib import Path
import time
import json
import hashlib

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def _resolve_repo_root():
    env_root = os.environ.get("MULTIPROPOSAL_RUN_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()
    root = Path.cwd().resolve()
    while root != root.parent and not (root / "pyproject.toml").exists():
        root = root.parent
    return root

repo_root = _resolve_repo_root()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
src_path = repo_root / "src"
if src_path.exists() and str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from multiproposal.algorithms.mpcn import mpcn_step, mpcn_chain
from multiproposal.algorithms.mtpcn import mtpcn_step, mtpcn_chain
from multiproposal.algorithms.pcn import pcn_chain
from multiproposal.algorithms.mess import mess_step
from multiproposal.algorithms.effective_sample_size import estimate_effective_sample_size
from multiproposal.problems.toy_custom_likelihood import ToyCustomLikelihood2D
from multiproposal.utils.run_paths import format_float_tag
from multiproposal.plotting.figure_style import apply_pub_style

# %%
# reload 
import importlib
import multiproposal.plotting.sweep_plots 
importlib.reload(multiproposal.plotting.sweep_plots)
from multiproposal.plotting.sweep_plots import (
    plot_trace_grid,
    plot_ess_msjd_vs_rho,
    plot_ess_msjd_per_param_vs_rho,
    plot_rejection_vs_rho,
 )

# %%
def f_polar_twist(x, alpha, weight_x=1.0, weight_y=1.0):
    x1, x2 = x
    radius = np.sqrt(x1 ** 2 + x2 ** 2)
    comp1 = x1 * np.cos(alpha * weight_x * radius) - x2 * np.sin(alpha * weight_y * radius)
    comp2 = x1 * np.sin(alpha * weight_x * radius) + x2 * np.cos(alpha * weight_y * radius)
    return np.array([comp1, comp2])

def log_likelihood_polar_twist(x, y_obs, sigma=0.3, alpha=0.5, weight_x=1.0, weight_y=1.0):
    r = f_polar_twist(x, alpha=alpha, weight_x=weight_x, weight_y=weight_y) - y_obs
    return -0.5 * np.dot(r, r) / (sigma ** 2)

# %% [markdown]
# ## Posterior formulation (polar twist)
#
# Let $x = (x_1, x_2)^T \in \mathbb{R}^2$ and $r = \sqrt{x_1^2 + x_2^2}$. The forward map defined in the code is
#
# $$
# f(x;\alpha) = \begin{bmatrix}
# x_1 \cos(\alpha r) - x_2 \sin(\alpha r) \\
# x_1 \sin(\alpha r) + x_2 \cos(\alpha r)
# \end{bmatrix}.
# $$
#
# The data are generated as
#
# $$
# x_{\text{true}} \sim \mathcal{N}(\mu, C), \quad y_{\text{obs}} = f(x_{\text{true}};\alpha) + \varepsilon, \quad \varepsilon \sim \mathcal{N}(0, \sigma^2 I_2),
# $$
#
# with $\mu = (0,0)^T$, $C = \text{prior\_std}^2 \begin{bmatrix}1 & 0.3 \\ 0.3 & 0.5\end{bmatrix}$ and $\text{prior\_std}=2.0$ (so $C = 4\begin{bmatrix}1 & 0.3 \\ 0.3 & 0.5\end{bmatrix}$), $\sigma = \text{sigma\_noise}=1.0$, and $\alpha = 2.0$ in this notebook.
#
# The Gaussian likelihood implied by `log_likelihood_polar_twist` is
#
# $$
# p(y_{\text{obs}}\mid x) = (2\pi\sigma^2)^{-1}
# \exp\left(-\frac{1}{2\sigma^2}\left\|f(x;\alpha)-y_{\text{obs}}\right\|^2\right).
# $$
#
# The prior density is
#
# $$
# p(x) = (2\pi)^{-1} |C|^{-1/2}
# \exp\left(-\frac{1}{2}(x-\mu)^T C^{-1} (x-\mu)\right).
# $$
#
# Therefore the posterior is
#
# $$
# p(x\mid y_{\text{obs}}) \propto
# \exp\left(-\frac{1}{2\sigma^2}\left\|f(x;\alpha)-y_{\text{obs}}\right\|^2
# -\frac{1}{2}(x-\mu)^T C^{-1} (x-\mu)\right).
# $$
#
# Equivalently, the log-posterior (up to an additive constant) is
#
# $$
# \log p(x\mid y_{\text{obs}}) =
# -\frac{1}{2\sigma^2}\left\|f(x;\alpha)-y_{\text{obs}}\right\|^2
# -\frac{1}{2}(x-\mu)^T C^{-1} (x-\mu) + \text{const}.
# $$

# %%
# Example used in the paper
alpha = 2
sigma_noise = 1.0
prior_std = 2.0
prior_cov = prior_std ** 2 * np.array([[1.0, 0.3], [0.3, 0.5]])
prior_mean = np.zeros(2)
weight_x = 1
weight_y = 1

# # Testing another example
# alpha = 2
# sigma_noise = 3.0
# prior_std = 0.5
# prior_cov = prior_std ** 2 * np.array([[1.0, 0.7], [0.7, 0.5]])
# prior_mean = np.zeros(2)
# weight_x = 0.3
# weight_y = 4

# # lots of bananas
# alpha = 0.4
# sigma_noise = 3.0
# prior_std = 3
# prior_cov = prior_std ** 2 * np.array([[1.0, 0.3], [0.3, 1]])
# prior_mean = np.zeros(2)
# weight_x = 0.3
# weight_y = 4

data_seed = 202
rng = np.random.default_rng(data_seed)
prior_sample = rng.multivariate_normal(prior_mean, prior_cov)
theta_true = f_polar_twist(prior_sample, alpha=alpha, weight_x=weight_x, weight_y=weight_y)
y_obs = theta_true + rng.normal(0.0, sigma_noise, size=theta_true.shape)

def log_likelihood(x):
    return log_likelihood_polar_twist(x, y_obs, sigma=sigma_noise, alpha=alpha, weight_x=weight_x, weight_y=weight_y)

problem = ToyCustomLikelihood2D(
    log_likelihood_fn=log_likelihood,
    prior_mean=prior_mean,
    prior_cov=prior_cov,
 )

data_config = {
    'model': 'polar_twist',
    'alpha': alpha,
    'weight_x': weight_x,
    'weight_y': weight_y,
    'sigma_noise': sigma_noise,
    'prior_std': prior_std,
    'prior_cov': prior_cov.tolist(),
    'prior_mean': prior_mean.tolist(),
    'data_seed': data_seed,
}

print('y_obs:', y_obs)
print('True x:', prior_sample)
print('Log-posterior at prior mean:', problem.log_posterior(prior_mean))
# Out:
# y_obs: [ 1.59110063 -3.32997972]
# True x: [-3.13349585 -2.43303473]
# Log-posterior at prior mean: -6.810183087048239

# %%
# Sweep configuration (used for file naming)
n_iters = 300000
P_list = [10, 30, 50, 100]
# P_list = [10]
M_list = P_list
rho_list = [round(val, 3) for val in np.arange(0, 1.01, 0.025)]
burn_in = 5000
max_lag = 5000
plot_iter = 0
n_diag_samples = 100
seed_base = 202
run_pcn = False
run_mpcn = False
run_mtpcn = True
run_mess = False

algo_config = {
    'n_iters': n_iters,
    'burn_in': burn_in,
    'max_lag': max_lag,
    'n_diag_samples': n_diag_samples,
}
execution_config = {}
sweep_config = {
    'P_list': P_list,
    'M_list': M_list,
    'rho_list': rho_list,
    'seed_base': seed_base,
    'run_pcn': run_pcn,
    'run_mpcn': run_mpcn,
    'run_mtpcn': run_mtpcn,
    'run_mess': run_mess,
}

# Optional overrides to reuse an existing run directory exactly.
data_id_override = "data_h37adb6467e8e"
run_id_override = "rho_sweep_h3262d0adfe72"

def _canonicalize_payload(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    if isinstance(obj, (np.floating, np.integer)):
        return obj.item()
    if isinstance(obj, Path):
        return str(obj)
    if isinstance(obj, dict):
        return {key: _canonicalize_payload(val) for key, val in sorted(obj.items())}
    if isinstance(obj, (list, tuple)):
        return [_canonicalize_payload(val) for val in obj]
    return obj

def _stable_hash(payload, length=12):
    data = json.dumps(
        _canonicalize_payload(payload),
        sort_keys=True,
        separators=(",", ":"),
        ensure_ascii=True,
    ).encode("utf-8")
    return hashlib.sha256(data).hexdigest()[:length]

data_id_config = dict(data_config)

data_id = data_id_override or f"data_h{_stable_hash(data_id_config)}"
run_id_payload = {
    'algorithm': 'polar_twist_rho_sweep',
    'algorithm_config': algo_config,
    'sweep': sweep_config,
}
run_id = run_id_override or f"rho_sweep_h{_stable_hash(run_id_payload)}"

estimations_dir = repo_root / "estimations" / "polar_twist" / data_id / "sweep" / run_id
reports_dir = repo_root / "reports" / "polar_twist" / data_id / "sweep" / run_id
for path in (estimations_dir, reports_dir):
    path.mkdir(parents=True, exist_ok=True)

methods = []
if run_mpcn:
    methods.append("mpcn")
if run_mtpcn:
    methods.append("mtpcn")
if run_pcn:
    methods.append("pcn")
if run_mess:
    methods.append("mess")

run_config = {
    'dataset': 'polar_twist',
    'algorithm': 'polar_twist_rho_sweep',
    'methods': methods,
    'data': data_config,
    'algorithm_config': algo_config,
    'execution': execution_config,
    'sweep': sweep_config,
}
config_path = estimations_dir / "config.json"
if not config_path.exists():
    payload = dict(run_config)
    payload['data_id'] = data_id
    payload['run_id'] = run_id
    with open(config_path, 'w', encoding='utf-8') as handle:
        json.dump(payload, handle, indent=2)

rng_init = np.random.default_rng(seed_base)
x0 = problem.sample_prior(rng_init)

print('P_list:', P_list)
print('M_list:', M_list)
print('rho_list:', rho_list)
print('n_iters:', n_iters)
print('burn_in:', burn_in)
print('max_lag:', max_lag)
print('n_diag_samples:', n_diag_samples)
print('run_mpcn:', run_mpcn)
print('run_mtpcn:', run_mtpcn)
print('run_pcn:', run_pcn)
print('run_mess:', run_mess)
print('data_id:', data_id)
print('run_id:', run_id)
print('Run directory:', estimations_dir)
# Out:
# P_list: [10, 30, 50, 100]
# M_list: [10, 30, 50, 100]
# rho_list: [np.float64(0.0), np.float64(0.025), np.float64(0.05), np.float64(0.075), np.float64(0.1), np.float64(0.125), np.float64(0.15), np.float64(0.175), np.float64(0.2), np.float64(0.225), np.float64(0.25), np.float64(0.275), np.float64(0.3), np.float64(0.325), np.float64(0.35), np.float64(0.375), np.float64(0.4), np.float64(0.425), np.float64(0.45), np.float64(0.475), np.float64(0.5), np.float64(0.525), np.float64(0.55), np.float64(0.575), np.float64(0.6), np.float64(0.625), np.float64(0.65), np.float64(0.675), np.float64(0.7), np.float64(0.725), np.float64(0.75), np.float64(0.775), np.float64(0.8), np.float64(0.825), np.float64(0.85), np.float64(0.875), np.float64(0.9), np.float64(0.925), np.float64(0.95), np.float64(0.975), np.float64(1.0)]
# n_iters: 300000
# burn_in: 5000
# max_lag: 5000
# n_diag_samples: 100
# run_mpcn: False
# run_mtpcn: True
# run_pcn: False
# run_mess: False
# data_id: data_h37adb6467e8e
# run_id: rho_sweep_h3262d0adfe72
# Run directory: /home/senng/mcmc-internal/estimations/polar_twist/data_h37adb6467e8e/sweep/rho_sweep_h3262d0adfe72

# %%
def compute_msjd_per_param(chain):
    """Return per-parameter mean squared jump distance for a chain segment."""
    if chain.shape[0] < 2:
        return np.zeros(chain.shape[1])
    jumps = np.diff(chain, axis=0)
    msjd = np.mean(jumps * jumps, axis=0)
    return msjd


def compute_ess_per_param(chain, max_lag):
    """Estimate per-parameter ESS for a chain segment."""
    if chain.shape[0] < 2:
        return np.zeros(chain.shape[1])
    variances = np.var(chain, axis=0)
    if np.all(variances == 0):
        return np.zeros(chain.shape[1])
    ess_vals = estimate_effective_sample_size(chain, max_lag=max_lag)
    ess_vals = np.asarray(ess_vals, dtype=float)
    ess_vals[variances == 0] = 0.0
    return ess_vals


def summarize_chain_metrics(chain, runtime_sec, burn_in, max_lag):
    post = chain[burn_in:]
    ess_vals = compute_ess_per_param(post, max_lag=max_lag)
    msjd_vals = compute_msjd_per_param(post)
    ess_mean = float(np.nanmean(ess_vals)) if ess_vals.size else 0.0
    msjd_mean = float(np.nanmean(msjd_vals)) if msjd_vals.size else 0.0
    runtime_min = runtime_sec / 60.0
    ess_per_min = ess_mean / runtime_min if runtime_min > 0 else np.nan
    return {
        'runtime_sec': runtime_sec,
        'runtime_min': runtime_min,
        'ess_mean': ess_mean,
        'msjd_mean': msjd_mean,
        'ess_per_min': ess_per_min,
        'ess_per_param': ess_vals.tolist(),
        'msjd_per_param': msjd_vals.tolist(),
    }


def rho_to_tag(rho):
    return format_float_tag(rho, precision=5)


def chain_cache_paths(method, rho, seed_base, P=None):
    rho_tag = rho_to_tag(rho)
    if P is None:
        stem = f"{method}_rho{rho_tag}_seed{seed_base}"
    else:
        stem = f"{method}_P{P}_rho{rho_tag}_seed{seed_base}"
    chains_dir = estimations_dir / "chains"
    if method in {"mpcn", "mtpcn", "pcn"}:
        chains_dir = chains_dir / method
    samples_path = chains_dir / f"{stem}.npz"
    metrics_path = chains_dir / f"{stem}_metrics.json"
    return samples_path, metrics_path


def mess_cache_paths(method, P, seed_base):
    stem = f"{method}_M{P}_seed{seed_base}"
    chains_dir = estimations_dir / "chains"
    samples_path = chains_dir / f"{stem}.npz"
    metrics_path = chains_dir / f"{stem}_metrics.json"
    return samples_path, metrics_path


def save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec):
    payload = dict(metrics)
    payload['accept_rate'] = None if accept_rate is None else float(accept_rate)
    payload['runtime_sec'] = float(runtime_sec)
    metrics_path.parent.mkdir(parents=True, exist_ok=True)
    with open(metrics_path, 'w', encoding='utf-8') as handle:
        json.dump(payload, handle, indent=2)


def load_metrics_json(metrics_path):
    if not metrics_path.exists():
        return None
    with open(metrics_path, 'r', encoding='utf-8') as handle:
        return json.load(handle)


def save_chain_bundle(samples_path, metrics_path, chain, accept_rate, runtime_sec, metrics):
    samples_path.parent.mkdir(parents=True, exist_ok=True)
    accept_val = np.nan if accept_rate is None else float(accept_rate)
    np.savez_compressed(
        samples_path,
        chain=chain,
        accept_rate=accept_val,
        runtime_sec=float(runtime_sec),
    )
    save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec)


def load_chain_bundle(samples_path, metrics_path):
    if not samples_path.exists():
        return None
    data = np.load(samples_path, allow_pickle=False)
    chain = data['chain']
    accept_rate = float(data['accept_rate']) if 'accept_rate' in data else np.nan
    if np.isnan(accept_rate):
        accept_rate = None
    runtime_sec = float(data['runtime_sec']) if 'runtime_sec' in data else 0.0
    metrics = load_metrics_json(metrics_path)
    return chain, accept_rate, runtime_sec, metrics


def mpcn_diag_path(P, rho, seed_base):
    rho_tag = rho_to_tag(rho)
    diag_dir = estimations_dir / "diagnostics"
    return diag_dir / f"mpcn_P{P}_rho{rho_tag}_seed{seed_base}_diag.npz"


def save_mpcn_diagnostics(diag_path, snapshot, mean_dist_samples, mean_sq_dist_samples):
    if snapshot is None and (mean_dist_samples is None or len(mean_dist_samples) == 0):
        return
    diag_path.parent.mkdir(parents=True, exist_ok=True)
    np.savez_compressed(
        diag_path,
        snapshot=np.array(snapshot, dtype=object),
        mean_dist_samples=np.asarray(mean_dist_samples, dtype=float),
        mean_sq_dist_samples=np.asarray(mean_sq_dist_samples, dtype=float),
    )


def load_mpcn_diagnostics(diag_path):
    if not diag_path.exists():
        return None, np.asarray([], dtype=float), np.asarray([], dtype=float)
    data = np.load(diag_path, allow_pickle=True)
    snapshot = None
    if 'snapshot' in data:
        try:
            snapshot = data['snapshot'].item()
        except ValueError:
            snapshot = None
    mean_dist_samples = data['mean_dist_samples'] if 'mean_dist_samples' in data else np.asarray([], dtype=float)
    mean_sq_dist_samples = data['mean_sq_dist_samples'] if 'mean_sq_dist_samples' in data else np.asarray([], dtype=float)
    return snapshot, mean_dist_samples, mean_sq_dist_samples


def run_mpcn_chain(problem, x0, n_iters, rho, n_props, seed, diag_indices=None):
    rng = np.random.default_rng(seed)
    t0 = time.perf_counter()
    return_diag = diag_indices is not None
    if return_diag:
        chain, accepted_index, diagnostics = mpcn_chain(
            x0,
            problem,
            rng,
            n_iters,
            rho=rho,
            n_props=n_props,
            return_indices=True,
            return_diagnostics=True,
            diag_indices=diag_indices,
        )
    else:
        chain, accepted_index = mpcn_chain(
            x0,
            problem,
            rng,
            n_iters,
            rho=rho,
            n_props=n_props,
            return_indices=True,
        )
        diagnostics = None
    runtime_sec = time.perf_counter() - t0
    accept_rate = float(np.mean(accepted_index != 0))
    return chain, runtime_sec, accept_rate, diagnostics


def run_mtpcn_chain(problem, x0, n_iters, rho, n_props, seed, diag_indices=None):
    rng = np.random.default_rng(seed)
    t0 = time.perf_counter()
    if diag_indices is not None:
        chain, accept_rate, _, diagnostics = mtpcn_chain(
            x0,
            problem,
            rng,
            n_iters,
            rho=rho,
            n_props=n_props,
            return_indices=True,
            return_diagnostics=True,
            diag_indices=diag_indices,
        )
    else:
        chain, accept_rate = mtpcn_chain(
            x0,
            problem,
            rng,
            n_iters,
            rho=rho,
            n_props=n_props,
        )
        diagnostics = None
    runtime_sec = time.perf_counter() - t0
    return chain, runtime_sec, float(accept_rate), diagnostics


def run_mess_chain(problem, x0, n_iters, M, seed, use_lp=False, distance_metric='angular', lam=0.0):
    rng = np.random.default_rng(seed)
    chain = np.zeros((n_iters + 1, problem.dim), dtype=float)
    chain[0] = x0
    x = x0.copy()
    t0 = time.perf_counter()
    for t in range(n_iters):
        x, _, _ = mess_step(
            x,
            problem,
            rng,
            M=M,
            use_lp=use_lp,
            distance_metric=distance_metric,
            lam=lam,
        )
        chain[t + 1] = x
    runtime_sec = time.perf_counter() - t0
    return chain, runtime_sec

# %%
# Precompute likelihood grid for plotting
grid_min = -8.0
grid_max = 8.0
grid = np.linspace(grid_min, grid_max, 300)
X1, X2 = np.meshgrid(grid, grid)
log_like = np.zeros_like(X1)
for i in range(X1.shape[0]):
    for j in range(X1.shape[1]):
        x_grid = np.array([X1[i, j], X2[i, j]])
        log_like[i, j] = log_likelihood_polar_twist(x_grid, y_obs, sigma=sigma_noise, alpha=alpha, weight_x=weight_x, weight_y=weight_y)
log_like -= log_like.max()
like_density = np.exp(log_like)

theta = np.linspace(0.0, 2.0 * np.pi, 800)
levels_fill = 50
levels_line = 14

# %%
# Load cached sweep results (chains are generated by the jobs script)
results = {
    'mpcn': {},
    'mtpcn': {},
    'pcn': {},
    'mess_uniform': {},
    'mess_euclid_sq': {},
}
run_pcn = True
run_mpcn = True
run_mtpcn = True
run_mess = False

missing = []
job_dir = repo_root / "jobs" / "polar_twist" / f"{run_id}_{data_id}"

if run_pcn:
    for rho in rho_list:
        samples_path, metrics_path = chain_cache_paths('pcn', rho=rho, seed_base=seed_base)
        loaded = load_chain_bundle(samples_path, metrics_path)
        if loaded is None:
            missing.append(f"pcn rho={rho:.3f}")
            continue
        chain, accept_rate, runtime_sec, metrics = loaded
        if metrics is None or 'ess_per_param' not in metrics:
            metrics = summarize_chain_metrics(
                chain, runtime_sec, burn_in=burn_in, max_lag=max_lag
            )
            save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec)
        results['pcn'][rho] = {
            'chain': chain,
            'runtime_sec': runtime_sec,
            'accept_rate': accept_rate,
            'metrics': metrics,
        }
        accept_display = np.nan if accept_rate is None else accept_rate
        print(
            f'pCN loaded: rho={rho:.3f}, accept={accept_display:.3f}, runtime={runtime_sec:.2f}s'
        )
else:
    print('pCN disabled (run_pcn=False).')

if run_mpcn:
    for P in P_list:
        results['mpcn'][P] = {}
        for rho in rho_list:
            samples_path, metrics_path = chain_cache_paths('mpcn', rho=rho, seed_base=seed_base, P=P)
            diag_path = mpcn_diag_path(P, rho, seed_base)
            loaded = load_chain_bundle(samples_path, metrics_path)
            if loaded is None:
                missing.append(f"mpcn P={P} rho={rho:.3f}")
                continue
            chain, accept_rate, runtime_sec, metrics = loaded
            if metrics is None or 'ess_per_param' not in metrics:
                metrics = summarize_chain_metrics(
                    chain, runtime_sec, burn_in=burn_in, max_lag=max_lag
                )
                save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec)
            snapshot, mean_dist_samples, mean_sq_dist_samples = load_mpcn_diagnostics(diag_path)
            results['mpcn'][P][rho] = {
                'chain': chain,
                'runtime_sec': runtime_sec,
                'accept_rate': accept_rate,
                'metrics': metrics,
                'snapshot': snapshot,
                'mean_dist_samples': np.asarray(mean_dist_samples, dtype=float),
                'mean_sq_dist_samples': np.asarray(mean_sq_dist_samples, dtype=float),
            }
            accept_display = np.nan if accept_rate is None else accept_rate
            print(
                f'mpCN loaded: P={P}, rho={rho:.3f}, accept={accept_display:.3f}, runtime={runtime_sec:.2f}s'
            )
else:
    print('mPCN disabled (run_mpcn=False).')

if run_mtpcn:
    for P in P_list:
        results['mtpcn'][P] = {}
        for rho in rho_list:
            samples_path, metrics_path = chain_cache_paths('mtpcn', rho=rho, seed_base=seed_base, P=P)
            loaded = load_chain_bundle(samples_path, metrics_path)
            if loaded is None:
                missing.append(f"mtpcn P={P} rho={rho:.3f}")
                continue
            chain, accept_rate, runtime_sec, metrics = loaded
            if metrics is None or 'ess_per_param' not in metrics:
                metrics = summarize_chain_metrics(
                    chain, runtime_sec, burn_in=burn_in, max_lag=max_lag
                )
                save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec)
            results['mtpcn'][P][rho] = {
                'chain': chain,
                'runtime_sec': runtime_sec,
                'accept_rate': accept_rate,
                'metrics': metrics,
            }
            accept_display = np.nan if accept_rate is None else accept_rate
            print(
                f'mtPCN loaded: P={P}, rho={rho:.3f}, accept={accept_display:.3f}, runtime={runtime_sec:.2f}s'
            )
else:
    print('mTPCN disabled (run_mtpcn=False).')

if run_mess:
    for P in P_list:
        samples_path, metrics_path = mess_cache_paths('mess_uniform', P=P, seed_base=seed_base)
        loaded = load_chain_bundle(samples_path, metrics_path)
        if loaded is None:
            missing.append(f"mess_uniform M={P}")
        else:
            mess_chain, _, mess_runtime, mess_metrics = loaded
            if mess_metrics is None or 'ess_per_param' not in mess_metrics:
                mess_metrics = summarize_chain_metrics(
                    mess_chain, mess_runtime, burn_in=burn_in, max_lag=max_lag
                )
                save_metrics_json(metrics_path, mess_metrics, None, mess_runtime)
            results['mess_uniform'][P] = {
                'chain': mess_chain,
                'runtime_sec': mess_runtime,
                'metrics': mess_metrics,
            }
            print(f'MESS uniform loaded: M={P}, runtime={mess_runtime:.2f}s')

        samples_path, metrics_path = mess_cache_paths('mess_euclid_sq', P=P, seed_base=seed_base)
        loaded = load_chain_bundle(samples_path, metrics_path)
        if loaded is None:
            missing.append(f"mess_euclid_sq M={P}")
        else:
            mess_lp_chain, _, mess_lp_runtime, mess_lp_metrics = loaded
            if mess_lp_metrics is None or 'ess_per_param' not in mess_lp_metrics:
                mess_lp_metrics = summarize_chain_metrics(
                    mess_lp_chain, mess_lp_runtime, burn_in=burn_in, max_lag=max_lag
                )
                save_metrics_json(metrics_path, mess_lp_metrics, None, mess_lp_runtime)
            results['mess_euclid_sq'][P] = {
                'chain': mess_lp_chain,
                'runtime_sec': mess_lp_runtime,
                'metrics': mess_lp_metrics,
            }
            print(f'MESS euclid_sq loaded: M={P}, runtime={mess_lp_runtime:.2f}s')
else:
    for P in P_list:
        results['mess_uniform'][P] = None
        results['mess_euclid_sq'][P] = None
        print(f'MESS disabled for M={P} (run_mess=False).')

if missing:
    preview = "\n".join(missing[:10])
    raise RuntimeError(
        "Missing chain outputs. Run the job script to generate chains, then re-run this cell.\n"
        f"Job dir: {job_dir}\n"
        f"Example: bash {job_dir / 'launch_workers.sh'}\n"
        f"Missing ({len(missing)}):\n{preview}"
    )
# Out:
# pCN loaded: rho=0.000, accept=0.108, runtime=2.20s
# pCN loaded: rho=0.025, accept=0.108, runtime=2.23s
# pCN loaded: rho=0.050, accept=0.108, runtime=2.23s
# pCN loaded: rho=0.075, accept=0.109, runtime=2.28s
# pCN loaded: rho=0.100, accept=0.108, runtime=2.25s
# pCN loaded: rho=0.125, accept=0.109, runtime=2.20s
# pCN loaded: rho=0.150, accept=0.109, runtime=2.21s
# pCN loaded: rho=0.175, accept=0.111, runtime=2.24s
# pCN loaded: rho=0.200, accept=0.108, runtime=2.20s
# pCN loaded: rho=0.225, accept=0.112, runtime=2.20s
# pCN loaded: rho=0.250, accept=0.110, runtime=2.21s
# pCN loaded: rho=0.275, accept=0.113, runtime=2.20s
# pCN loaded: rho=0.300, accept=0.114, runtime=2.23s
# pCN loaded: rho=0.325, accept=0.115, runtime=2.21s
# pCN loaded: rho=0.350, accept=0.116, runtime=2.20s
# pCN loaded: rho=0.375, accept=0.115, runtime=2.20s
# pCN loaded: rho=0.400, accept=0.116, runtime=2.21s
# pCN loaded: rho=0.425, accept=0.118, runtime=2.22s
# pCN loaded: rho=0.450, accept=0.120, runtime=2.22s
# pCN loaded: rho=0.475, accept=0.121, runtime=2.21s
# pCN loaded: rho=0.500, accept=0.123, runtime=2.22s
# pCN loaded: rho=0.525, accept=0.125, runtime=2.21s
# pCN loaded: rho=0.550, accept=0.128, runtime=2.21s
# pCN loaded: rho=0.575, accept=0.130, runtime=2.26s
# pCN loaded: rho=0.600, accept=0.131, runtime=2.20s
# pCN loaded: rho=0.625, accept=0.136, runtime=2.24s
# pCN loaded: rho=0.650, accept=0.138, runtime=2.20s
# pCN loaded: rho=0.675, accept=0.142, runtime=2.21s
# pCN loaded: rho=0.700, accept=0.146, runtime=2.23s
# pCN loaded: rho=0.725, accept=0.152, runtime=2.23s
# pCN loaded: rho=0.750, accept=0.155, runtime=2.26s
# pCN loaded: rho=0.775, accept=0.164, runtime=2.20s
# pCN loaded: rho=0.800, accept=0.173, runtime=2.25s
# pCN loaded: rho=0.825, accept=0.184, runtime=2.31s
# pCN loaded: rho=0.850, accept=0.194, runtime=2.26s
# pCN loaded: rho=0.875, accept=0.209, runtime=2.22s
# pCN loaded: rho=0.900, accept=0.231, runtime=2.30s
# pCN loaded: rho=0.925, accept=0.267, runtime=2.29s
# pCN loaded: rho=0.950, accept=0.314, runtime=2.32s
# pCN loaded: rho=0.975, accept=0.412, runtime=2.22s
# pCN loaded: rho=1.000, accept=1.000, runtime=2.12s
# mpCN loaded: P=10, rho=0.000, accept=0.459, runtime=29.54s
# mpCN loaded: P=10, rho=0.025, accept=0.459, runtime=32.62s
# mpCN loaded: P=10, rho=0.050, accept=0.460, runtime=27.08s
# mpCN loaded: P=10, rho=0.075, accept=0.458, runtime=34.06s
# mpCN loaded: P=10, rho=0.100, accept=0.459, runtime=31.17s
# mpCN loaded: P=10, rho=0.125, accept=0.457, runtime=30.19s
# mpCN loaded: P=10, rho=0.150, accept=0.457, runtime=37.40s
# mpCN loaded: P=10, rho=0.175, accept=0.457, runtime=36.17s
# mpCN loaded: P=10, rho=0.200, accept=0.459, runtime=32.75s
# mpCN loaded: P=10, rho=0.225, accept=0.458, runtime=29.27s
# mpCN loaded: P=10, rho=0.250, accept=0.460, runtime=33.67s
# mpCN loaded: P=10, rho=0.275, accept=0.461, runtime=30.08s
# mpCN loaded: P=10, rho=0.300, accept=0.461, runtime=34.36s
# mpCN loaded: P=10, rho=0.325, accept=0.457, runtime=29.73s
# mpCN loaded: P=10, rho=0.350, accept=0.461, runtime=32.73s
# mpCN loaded: P=10, rho=0.375, accept=0.461, runtime=31.08s
# mpCN loaded: P=10, rho=0.400, accept=0.462, runtime=29.47s
# mpCN loaded: P=10, rho=0.425, accept=0.463, runtime=19.97s
# mpCN loaded: P=10, rho=0.450, accept=0.463, runtime=30.45s
# mpCN loaded: P=10, rho=0.475, accept=0.463, runtime=29.70s
# mpCN loaded: P=10, rho=0.500, accept=0.465, runtime=30.14s
# mpCN loaded: P=10, rho=0.525, accept=0.465, runtime=29.62s
# mpCN loaded: P=10, rho=0.550, accept=0.467, runtime=29.66s
# mpCN loaded: P=10, rho=0.575, accept=0.471, runtime=30.83s
# mpCN loaded: P=10, rho=0.600, accept=0.470, runtime=30.42s
# mpCN loaded: P=10, rho=0.625, accept=0.473, runtime=20.25s
# mpCN loaded: P=10, rho=0.650, accept=0.473, runtime=30.47s
# mpCN loaded: P=10, rho=0.675, accept=0.477, runtime=29.92s
# mpCN loaded: P=10, rho=0.700, accept=0.482, runtime=31.33s
# mpCN loaded: P=10, rho=0.725, accept=0.486, runtime=29.77s
# mpCN loaded: P=10, rho=0.750, accept=0.491, runtime=31.16s
# mpCN loaded: P=10, rho=0.775, accept=0.499, runtime=30.98s
# mpCN loaded: P=10, rho=0.800, accept=0.507, runtime=36.04s
# mpCN loaded: P=10, rho=0.825, accept=0.515, runtime=21.44s
# mpCN loaded: P=10, rho=0.850, accept=0.529, runtime=30.54s
# mpCN loaded: P=10, rho=0.875, accept=0.546, runtime=30.14s
# mpCN loaded: P=10, rho=0.900, accept=0.566, runtime=30.23s
# mpCN loaded: P=10, rho=0.925, accept=0.598, runtime=30.13s
# mpCN loaded: P=10, rho=0.950, accept=0.639, runtime=29.79s
# mpCN loaded: P=10, rho=0.975, accept=0.711, runtime=31.43s
# mpCN loaded: P=10, rho=1.000, accept=0.909, runtime=28.74s
# mpCN loaded: P=30, rho=0.000, accept=0.728, runtime=61.76s
# mpCN loaded: P=30, rho=0.025, accept=0.726, runtime=66.24s
# mpCN loaded: P=30, rho=0.050, accept=0.727, runtime=62.43s
# mpCN loaded: P=30, rho=0.075, accept=0.726, runtime=76.57s
# mpCN loaded: P=30, rho=0.100, accept=0.727, runtime=61.93s
# mpCN loaded: P=30, rho=0.125, accept=0.726, runtime=63.07s
# mpCN loaded: P=30, rho=0.150, accept=0.727, runtime=60.24s
# mpCN loaded: P=30, rho=0.175, accept=0.727, runtime=62.46s
# mpCN loaded: P=30, rho=0.200, accept=0.727, runtime=60.31s
# mpCN loaded: P=30, rho=0.225, accept=0.727, runtime=62.30s
# mpCN loaded: P=30, rho=0.250, accept=0.729, runtime=61.36s
# mpCN loaded: P=30, rho=0.275, accept=0.728, runtime=61.96s
# mpCN loaded: P=30, rho=0.300, accept=0.727, runtime=59.59s
# mpCN loaded: P=30, rho=0.325, accept=0.729, runtime=60.53s
# mpCN loaded: P=30, rho=0.350, accept=0.729, runtime=59.96s
# mpCN loaded: P=30, rho=0.375, accept=0.732, runtime=61.92s
# mpCN loaded: P=30, rho=0.400, accept=0.729, runtime=61.39s
# mpCN loaded: P=30, rho=0.425, accept=0.731, runtime=62.46s
# mpCN loaded: P=30, rho=0.450, accept=0.730, runtime=62.04s
# mpCN loaded: P=30, rho=0.475, accept=0.730, runtime=61.82s
# mpCN loaded: P=30, rho=0.500, accept=0.733, runtime=61.23s
# mpCN loaded: P=30, rho=0.525, accept=0.734, runtime=60.64s
# mpCN loaded: P=30, rho=0.550, accept=0.732, runtime=64.17s
# mpCN loaded: P=30, rho=0.575, accept=0.734, runtime=62.12s
# mpCN loaded: P=30, rho=0.600, accept=0.738, runtime=60.30s
# mpCN loaded: P=30, rho=0.625, accept=0.737, runtime=62.10s
# mpCN loaded: P=30, rho=0.650, accept=0.738, runtime=61.45s
# mpCN loaded: P=30, rho=0.675, accept=0.740, runtime=60.68s
# mpCN loaded: P=30, rho=0.700, accept=0.743, runtime=59.66s
# mpCN loaded: P=30, rho=0.725, accept=0.745, runtime=59.84s
# mpCN loaded: P=30, rho=0.750, accept=0.749, runtime=59.83s
# mpCN loaded: P=30, rho=0.775, accept=0.753, runtime=62.26s
# mpCN loaded: P=30, rho=0.800, accept=0.758, runtime=62.01s
# mpCN loaded: P=30, rho=0.825, accept=0.764, runtime=62.72s
# mpCN loaded: P=30, rho=0.850, accept=0.774, runtime=62.17s
# mpCN loaded: P=30, rho=0.875, accept=0.782, runtime=61.32s
# mpCN loaded: P=30, rho=0.900, accept=0.795, runtime=61.75s
# mpCN loaded: P=30, rho=0.925, accept=0.812, runtime=60.55s
# mpCN loaded: P=30, rho=0.950, accept=0.837, runtime=43.28s
# mpCN loaded: P=30, rho=0.975, accept=0.874, runtime=60.94s
# mpCN loaded: P=30, rho=1.000, accept=0.967, runtime=57.69s
# mpCN loaded: P=50, rho=0.000, accept=0.819, runtime=92.37s
# mpCN loaded: P=50, rho=0.025, accept=0.820, runtime=91.76s
# mpCN loaded: P=50, rho=0.050, accept=0.819, runtime=89.86s
# mpCN loaded: P=50, rho=0.075, accept=0.819, runtime=90.79s
# mpCN loaded: P=50, rho=0.100, accept=0.821, runtime=89.26s
# mpCN loaded: P=50, rho=0.125, accept=0.820, runtime=92.38s
# mpCN loaded: P=50, rho=0.150, accept=0.820, runtime=91.77s
# mpCN loaded: P=50, rho=0.175, accept=0.821, runtime=62.64s
# mpCN loaded: P=50, rho=0.200, accept=0.821, runtime=92.72s
# mpCN loaded: P=50, rho=0.225, accept=0.820, runtime=92.20s
# mpCN loaded: P=50, rho=0.250, accept=0.820, runtime=92.15s
# mpCN loaded: P=50, rho=0.275, accept=0.821, runtime=90.73s
# mpCN loaded: P=50, rho=0.300, accept=0.821, runtime=67.30s
# mpCN loaded: P=50, rho=0.325, accept=0.820, runtime=92.54s
# mpCN loaded: P=50, rho=0.350, accept=0.823, runtime=90.22s
# mpCN loaded: P=50, rho=0.375, accept=0.823, runtime=61.52s
# mpCN loaded: P=50, rho=0.400, accept=0.822, runtime=92.83s
# mpCN loaded: P=50, rho=0.425, accept=0.823, runtime=91.22s
# mpCN loaded: P=50, rho=0.450, accept=0.823, runtime=90.32s
# mpCN loaded: P=50, rho=0.475, accept=0.823, runtime=90.53s
# mpCN loaded: P=50, rho=0.500, accept=0.824, runtime=89.83s
# mpCN loaded: P=50, rho=0.525, accept=0.824, runtime=92.28s
# mpCN loaded: P=50, rho=0.550, accept=0.827, runtime=81.96s
# mpCN loaded: P=50, rho=0.575, accept=0.827, runtime=78.95s
# mpCN loaded: P=50, rho=0.600, accept=0.827, runtime=93.68s
# mpCN loaded: P=50, rho=0.625, accept=0.829, runtime=91.73s
# mpCN loaded: P=50, rho=0.650, accept=0.828, runtime=92.63s
# mpCN loaded: P=50, rho=0.675, accept=0.829, runtime=90.72s
# mpCN loaded: P=50, rho=0.700, accept=0.831, runtime=82.25s
# mpCN loaded: P=50, rho=0.725, accept=0.832, runtime=91.94s
# mpCN loaded: P=50, rho=0.750, accept=0.835, runtime=90.79s
# mpCN loaded: P=50, rho=0.775, accept=0.837, runtime=83.13s
# mpCN loaded: P=50, rho=0.800, accept=0.840, runtime=92.31s
# mpCN loaded: P=50, rho=0.825, accept=0.844, runtime=90.92s
# mpCN loaded: P=50, rho=0.850, accept=0.849, runtime=89.79s
# mpCN loaded: P=50, rho=0.875, accept=0.856, runtime=90.67s
# mpCN loaded: P=50, rho=0.900, accept=0.866, runtime=90.14s
# mpCN loaded: P=50, rho=0.925, accept=0.878, runtime=91.07s
# mpCN loaded: P=50, rho=0.950, accept=0.893, runtime=92.15s
# mpCN loaded: P=50, rho=0.975, accept=0.916, runtime=90.23s
# mpCN loaded: P=50, rho=1.000, accept=0.980, runtime=90.02s
# mpCN loaded: P=100, rho=0.000, accept=0.903, runtime=169.49s
# mpCN loaded: P=100, rho=0.025, accept=0.903, runtime=167.31s
# mpCN loaded: P=100, rho=0.050, accept=0.904, runtime=141.39s
# mpCN loaded: P=100, rho=0.075, accept=0.904, runtime=164.32s
# mpCN loaded: P=100, rho=0.100, accept=0.903, runtime=164.85s
# mpCN loaded: P=100, rho=0.125, accept=0.904, runtime=170.42s
# mpCN loaded: P=100, rho=0.150, accept=0.905, runtime=169.84s
# mpCN loaded: P=100, rho=0.175, accept=0.904, runtime=172.78s
# mpCN loaded: P=100, rho=0.200, accept=0.904, runtime=164.45s
# mpCN loaded: P=100, rho=0.225, accept=0.904, runtime=164.55s
# mpCN loaded: P=100, rho=0.250, accept=0.904, runtime=168.63s
# mpCN loaded: P=100, rho=0.275, accept=0.905, runtime=164.22s
# mpCN loaded: P=100, rho=0.300, accept=0.905, runtime=169.15s
# mpCN loaded: P=100, rho=0.325, accept=0.905, runtime=157.88s
# mpCN loaded: P=100, rho=0.350, accept=0.904, runtime=171.62s
# mpCN loaded: P=100, rho=0.375, accept=0.905, runtime=169.47s
# mpCN loaded: P=100, rho=0.400, accept=0.905, runtime=170.60s
# mpCN loaded: P=100, rho=0.425, accept=0.905, runtime=160.62s
# mpCN loaded: P=100, rho=0.450, accept=0.906, runtime=116.82s
# mpCN loaded: P=100, rho=0.475, accept=0.906, runtime=159.42s
# mpCN loaded: P=100, rho=0.500, accept=0.906, runtime=167.74s
# mpCN loaded: P=100, rho=0.525, accept=0.907, runtime=166.48s
# mpCN loaded: P=100, rho=0.550, accept=0.908, runtime=170.30s
# mpCN loaded: P=100, rho=0.575, accept=0.907, runtime=166.00s
# mpCN loaded: P=100, rho=0.600, accept=0.907, runtime=165.84s
# mpCN loaded: P=100, rho=0.625, accept=0.908, runtime=160.72s
# mpCN loaded: P=100, rho=0.650, accept=0.909, runtime=117.87s
# mpCN loaded: P=100, rho=0.675, accept=0.909, runtime=159.89s
# mpCN loaded: P=100, rho=0.700, accept=0.909, runtime=169.73s
# mpCN loaded: P=100, rho=0.725, accept=0.911, runtime=166.91s
# mpCN loaded: P=100, rho=0.750, accept=0.912, runtime=171.42s
# mpCN loaded: P=100, rho=0.775, accept=0.913, runtime=166.14s
# mpCN loaded: P=100, rho=0.800, accept=0.914, runtime=168.60s
# mpCN loaded: P=100, rho=0.825, accept=0.916, runtime=161.47s
# mpCN loaded: P=100, rho=0.850, accept=0.918, runtime=129.99s
# mpCN loaded: P=100, rho=0.875, accept=0.922, runtime=160.42s
# mpCN loaded: P=100, rho=0.900, accept=0.927, runtime=164.82s
# mpCN loaded: P=100, rho=0.925, accept=0.933, runtime=162.30s
# mpCN loaded: P=100, rho=0.950, accept=0.941, runtime=165.43s
# mpCN loaded: P=100, rho=0.975, accept=0.955, runtime=166.86s
# mpCN loaded: P=100, rho=1.000, accept=0.990, runtime=158.17s
# mtPCN loaded: P=10, rho=0.000, accept=0.496, runtime=23.61s
# mtPCN loaded: P=10, rho=0.025, accept=0.496, runtime=23.50s
# mtPCN loaded: P=10, rho=0.050, accept=0.498, runtime=22.44s
# mtPCN loaded: P=10, rho=0.075, accept=0.497, runtime=23.69s
# mtPCN loaded: P=10, rho=0.100, accept=0.500, runtime=23.02s
# mtPCN loaded: P=10, rho=0.125, accept=0.498, runtime=23.50s
# mtPCN loaded: P=10, rho=0.150, accept=0.499, runtime=23.27s
# mtPCN loaded: P=10, rho=0.175, accept=0.502, runtime=22.65s
# mtPCN loaded: P=10, rho=0.200, accept=0.502, runtime=24.03s
# mtPCN loaded: P=10, rho=0.225, accept=0.508, runtime=23.92s
# mtPCN loaded: P=10, rho=0.250, accept=0.507, runtime=23.28s
# mtPCN loaded: P=10, rho=0.275, accept=0.510, runtime=23.70s
# mtPCN loaded: P=10, rho=0.300, accept=0.512, runtime=23.50s
# mtPCN loaded: P=10, rho=0.325, accept=0.511, runtime=23.67s
# mtPCN loaded: P=10, rho=0.350, accept=0.515, runtime=23.74s
# mtPCN loaded: P=10, rho=0.375, accept=0.518, runtime=23.69s
# mtPCN loaded: P=10, rho=0.400, accept=0.519, runtime=29.32s
# mtPCN loaded: P=10, rho=0.425, accept=0.522, runtime=28.70s
# mtPCN loaded: P=10, rho=0.450, accept=0.527, runtime=28.01s
# mtPCN loaded: P=10, rho=0.475, accept=0.528, runtime=28.25s
# mtPCN loaded: P=10, rho=0.500, accept=0.534, runtime=28.32s
# mtPCN loaded: P=10, rho=0.525, accept=0.538, runtime=29.08s
# mtPCN loaded: P=10, rho=0.550, accept=0.541, runtime=28.72s
# mtPCN loaded: P=10, rho=0.575, accept=0.547, runtime=28.94s
# mtPCN loaded: P=10, rho=0.600, accept=0.553, runtime=29.59s
# mtPCN loaded: P=10, rho=0.625, accept=0.559, runtime=28.89s
# mtPCN loaded: P=10, rho=0.650, accept=0.565, runtime=28.43s
# mtPCN loaded: P=10, rho=0.675, accept=0.572, runtime=28.44s
# mtPCN loaded: P=10, rho=0.700, accept=0.580, runtime=28.65s
# mtPCN loaded: P=10, rho=0.725, accept=0.587, runtime=29.34s
# mtPCN loaded: P=10, rho=0.750, accept=0.596, runtime=28.93s
# mtPCN loaded: P=10, rho=0.775, accept=0.608, runtime=29.27s
# mtPCN loaded: P=10, rho=0.800, accept=0.619, runtime=50.27s
# mtPCN loaded: P=10, rho=0.825, accept=0.630, runtime=50.20s
# mtPCN loaded: P=10, rho=0.850, accept=0.646, runtime=50.58s
# mtPCN loaded: P=10, rho=0.875, accept=0.664, runtime=48.15s
# mtPCN loaded: P=10, rho=0.900, accept=0.683, runtime=33.44s
# mtPCN loaded: P=10, rho=0.925, accept=0.712, runtime=50.18s
# mtPCN loaded: P=10, rho=0.950, accept=0.743, runtime=50.25s
# mtPCN loaded: P=10, rho=0.975, accept=0.800, runtime=50.44s
# mtPCN loaded: P=10, rho=1.000, accept=1.000, runtime=48.67s
# mtPCN loaded: P=30, rho=0.000, accept=0.692, runtime=110.93s
# mtPCN loaded: P=30, rho=0.025, accept=0.693, runtime=85.11s
# mtPCN loaded: P=30, rho=0.050, accept=0.694, runtime=78.57s
# mtPCN loaded: P=30, rho=0.075, accept=0.693, runtime=75.51s
# mtPCN loaded: P=30, rho=0.100, accept=0.695, runtime=77.37s
# mtPCN loaded: P=30, rho=0.125, accept=0.696, runtime=110.32s
# mtPCN loaded: P=30, rho=0.150, accept=0.697, runtime=105.66s
# mtPCN loaded: P=30, rho=0.175, accept=0.697, runtime=110.91s
# mtPCN loaded: P=30, rho=0.200, accept=0.699, runtime=111.27s
# mtPCN loaded: P=30, rho=0.225, accept=0.701, runtime=76.53s
# mtPCN loaded: P=30, rho=0.250, accept=0.701, runtime=76.24s
# mtPCN loaded: P=30, rho=0.275, accept=0.702, runtime=80.55s
# mtPCN loaded: P=30, rho=0.300, accept=0.704, runtime=75.60s
# mtPCN loaded: P=30, rho=0.325, accept=0.705, runtime=110.79s
# mtPCN loaded: P=30, rho=0.350, accept=0.707, runtime=77.99s
# mtPCN loaded: P=30, rho=0.375, accept=0.708, runtime=84.46s
# mtPCN loaded: P=30, rho=0.400, accept=0.708, runtime=75.45s
# mtPCN loaded: P=30, rho=0.425, accept=0.711, runtime=89.81s
# mtPCN loaded: P=30, rho=0.450, accept=0.713, runtime=91.74s
# mtPCN loaded: P=30, rho=0.475, accept=0.715, runtime=78.84s
# mtPCN loaded: P=30, rho=0.500, accept=0.716, runtime=90.47s
# mtPCN loaded: P=30, rho=0.525, accept=0.720, runtime=110.51s
# mtPCN loaded: P=30, rho=0.550, accept=0.722, runtime=73.72s
# mtPCN loaded: P=30, rho=0.575, accept=0.727, runtime=77.66s
# mtPCN loaded: P=30, rho=0.600, accept=0.729, runtime=98.05s
# mtPCN loaded: P=30, rho=0.625, accept=0.731, runtime=109.40s
# mtPCN loaded: P=30, rho=0.650, accept=0.736, runtime=101.51s
# mtPCN loaded: P=30, rho=0.675, accept=0.739, runtime=77.74s
# mtPCN loaded: P=30, rho=0.700, accept=0.743, runtime=110.61s
# mtPCN loaded: P=30, rho=0.725, accept=0.748, runtime=81.73s
# mtPCN loaded: P=30, rho=0.750, accept=0.751, runtime=112.15s
# mtPCN loaded: P=30, rho=0.775, accept=0.757, runtime=110.59s
# mtPCN loaded: P=30, rho=0.800, accept=0.764, runtime=101.36s
# mtPCN loaded: P=30, rho=0.825, accept=0.771, runtime=83.61s
# mtPCN loaded: P=30, rho=0.850, accept=0.781, runtime=73.59s
# mtPCN loaded: P=30, rho=0.875, accept=0.791, runtime=100.30s
# mtPCN loaded: P=30, rho=0.900, accept=0.805, runtime=82.63s
# mtPCN loaded: P=30, rho=0.925, accept=0.822, runtime=74.37s
# mtPCN loaded: P=30, rho=0.950, accept=0.845, runtime=111.52s
# mtPCN loaded: P=30, rho=0.975, accept=0.873, runtime=111.10s
# mtPCN loaded: P=30, rho=1.000, accept=1.000, runtime=76.30s
# mtPCN loaded: P=50, rho=0.000, accept=0.760, runtime=165.00s
# mtPCN loaded: P=50, rho=0.025, accept=0.761, runtime=112.30s
# mtPCN loaded: P=50, rho=0.050, accept=0.762, runtime=114.60s
# mtPCN loaded: P=50, rho=0.075, accept=0.761, runtime=144.20s
# mtPCN loaded: P=50, rho=0.100, accept=0.761, runtime=130.33s
# mtPCN loaded: P=50, rho=0.125, accept=0.762, runtime=170.96s
# mtPCN loaded: P=50, rho=0.150, accept=0.763, runtime=170.73s
# mtPCN loaded: P=50, rho=0.175, accept=0.763, runtime=171.12s
# mtPCN loaded: P=50, rho=0.200, accept=0.764, runtime=132.67s
# mtPCN loaded: P=50, rho=0.225, accept=0.764, runtime=112.60s
# mtPCN loaded: P=50, rho=0.250, accept=0.765, runtime=171.19s
# mtPCN loaded: P=50, rho=0.275, accept=0.765, runtime=150.26s
# mtPCN loaded: P=50, rho=0.300, accept=0.767, runtime=171.36s
# mtPCN loaded: P=50, rho=0.325, accept=0.767, runtime=163.41s
# mtPCN loaded: P=50, rho=0.350, accept=0.769, runtime=170.93s
# mtPCN loaded: P=50, rho=0.375, accept=0.769, runtime=162.24s
# mtPCN loaded: P=50, rho=0.400, accept=0.771, runtime=168.58s
# mtPCN loaded: P=50, rho=0.425, accept=0.771, runtime=112.38s
# mtPCN loaded: P=50, rho=0.450, accept=0.774, runtime=170.67s
# mtPCN loaded: P=50, rho=0.475, accept=0.775, runtime=161.69s
# mtPCN loaded: P=50, rho=0.500, accept=0.776, runtime=172.02s
# mtPCN loaded: P=50, rho=0.525, accept=0.778, runtime=147.40s
# mtPCN loaded: P=50, rho=0.550, accept=0.778, runtime=171.05s
# mtPCN loaded: P=50, rho=0.575, accept=0.783, runtime=135.99s
# mtPCN loaded: P=50, rho=0.600, accept=0.784, runtime=170.43s
# mtPCN loaded: P=50, rho=0.625, accept=0.785, runtime=119.62s
# mtPCN loaded: P=50, rho=0.650, accept=0.787, runtime=170.26s
# mtPCN loaded: P=50, rho=0.675, accept=0.791, runtime=115.96s
# mtPCN loaded: P=50, rho=0.700, accept=0.793, runtime=113.17s
# mtPCN loaded: P=50, rho=0.725, accept=0.796, runtime=127.82s
# mtPCN loaded: P=50, rho=0.750, accept=0.799, runtime=115.57s
# mtPCN loaded: P=50, rho=0.775, accept=0.803, runtime=171.45s
# mtPCN loaded: P=50, rho=0.800, accept=0.807, runtime=159.14s
# mtPCN loaded: P=50, rho=0.825, accept=0.813, runtime=151.36s
# mtPCN loaded: P=50, rho=0.850, accept=0.820, runtime=118.21s
# mtPCN loaded: P=50, rho=0.875, accept=0.830, runtime=145.37s
# mtPCN loaded: P=50, rho=0.900, accept=0.839, runtime=151.61s
# mtPCN loaded: P=50, rho=0.925, accept=0.854, runtime=159.65s
# mtPCN loaded: P=50, rho=0.950, accept=0.871, runtime=171.13s
# mtPCN loaded: P=50, rho=0.975, accept=0.892, runtime=125.15s
# mtPCN loaded: P=50, rho=1.000, accept=1.000, runtime=166.20s
# mtPCN loaded: P=100, rho=0.000, accept=0.831, runtime=217.53s
# mtPCN loaded: P=100, rho=0.025, accept=0.829, runtime=284.51s
# mtPCN loaded: P=100, rho=0.050, accept=0.831, runtime=321.18s
# mtPCN loaded: P=100, rho=0.075, accept=0.831, runtime=239.08s
# mtPCN loaded: P=100, rho=0.100, accept=0.831, runtime=217.96s
# mtPCN loaded: P=100, rho=0.125, accept=0.831, runtime=322.80s
# mtPCN loaded: P=100, rho=0.150, accept=0.831, runtime=321.64s
# mtPCN loaded: P=100, rho=0.175, accept=0.833, runtime=322.78s
# mtPCN loaded: P=100, rho=0.200, accept=0.832, runtime=253.85s
# mtPCN loaded: P=100, rho=0.225, accept=0.830, runtime=320.66s
# mtPCN loaded: P=100, rho=0.250, accept=0.832, runtime=260.90s
# mtPCN loaded: P=100, rho=0.275, accept=0.831, runtime=261.65s
# mtPCN loaded: P=100, rho=0.300, accept=0.831, runtime=227.65s
# mtPCN loaded: P=100, rho=0.325, accept=0.831, runtime=322.04s
# mtPCN loaded: P=100, rho=0.350, accept=0.832, runtime=320.98s
# mtPCN loaded: P=100, rho=0.375, accept=0.832, runtime=320.15s
# mtPCN loaded: P=100, rho=0.400, accept=0.832, runtime=308.22s
# mtPCN loaded: P=100, rho=0.425, accept=0.833, runtime=233.58s
# mtPCN loaded: P=100, rho=0.450, accept=0.834, runtime=290.51s
# mtPCN loaded: P=100, rho=0.475, accept=0.832, runtime=211.77s
# mtPCN loaded: P=100, rho=0.500, accept=0.833, runtime=214.55s
# mtPCN loaded: P=100, rho=0.525, accept=0.833, runtime=320.80s
# mtPCN loaded: P=100, rho=0.550, accept=0.835, runtime=321.27s
# mtPCN loaded: P=100, rho=0.575, accept=0.836, runtime=282.37s
# mtPCN loaded: P=100, rho=0.600, accept=0.836, runtime=306.36s
# mtPCN loaded: P=100, rho=0.625, accept=0.836, runtime=222.26s
# mtPCN loaded: P=100, rho=0.650, accept=0.838, runtime=318.13s
# mtPCN loaded: P=100, rho=0.675, accept=0.839, runtime=257.14s
# mtPCN loaded: P=100, rho=0.700, accept=0.841, runtime=212.87s
# mtPCN loaded: P=100, rho=0.725, accept=0.842, runtime=211.39s
# mtPCN loaded: P=100, rho=0.750, accept=0.844, runtime=210.16s
# mtPCN loaded: P=100, rho=0.775, accept=0.847, runtime=227.31s
# mtPCN loaded: P=100, rho=0.800, accept=0.847, runtime=199.64s
# mtPCN loaded: P=100, rho=0.825, accept=0.852, runtime=214.61s
# mtPCN loaded: P=100, rho=0.850, accept=0.857, runtime=219.59s
# mtPCN loaded: P=100, rho=0.875, accept=0.866, runtime=217.53s
# mtPCN loaded: P=100, rho=0.900, accept=0.875, runtime=197.96s
# mtPCN loaded: P=100, rho=0.925, accept=0.887, runtime=135.88s
# mtPCN loaded: P=100, rho=0.950, accept=0.901, runtime=271.53s
# mtPCN loaded: P=100, rho=0.975, accept=0.913, runtime=158.97s
# mtPCN loaded: P=100, rho=1.000, accept=1.000, runtime=151.50s
# MESS disabled for M=10 (run_mess=False).
# MESS disabled for M=30 (run_mess=False).
# MESS disabled for M=50 (run_mess=False).
# MESS disabled for M=100 (run_mess=False).

# %%
# def plot_mpcn_snapshot(ax, snapshot, P, rho, iter_idx):
#     mu = problem.prior_mean()
#     x = snapshot['x']
#     nu_c = snapshot['nu_c']
#     props = snapshot['props']
#     candidates = snapshot['candidates']
#     logy = snapshot['logy']
#     accepted_idx = snapshot['accepted_idx']
#     mean_dist = snapshot['mean_dist']
#     mean_sq_dist = snapshot['mean_sq_dist']
#     ellipse = mu + np.cos(theta)[:, None] * (x - mu) + np.sin(theta)[:, None] * nu_c

#     ax.contourf(X1, X2, like_density, levels=levels_fill, cmap='Greys', alpha=0.35)
#     ax.contour(X1, X2, like_density, levels=levels_line, colors='black', linewidths=0.5, alpha=0.2)
#     ax.plot(ellipse[:, 0], ellipse[:, 1], color='black', linewidth=1.5, zorder=2)

#     prop_log_like = np.array([problem.log_likelihood(p) for p in props])
#     above = prop_log_like >= logy
#     ax.scatter(props[~above, 0], props[~above, 1], color='teal', s=10, alpha=0.8, label='props < logy', zorder=2)
#     ax.scatter(props[above, 0], props[above, 1], color='teal', s=10, alpha=0.8, label='props >= logy', zorder=2)
#     ax.scatter([x[0]], [x[1]], color='green', s=60, marker='o', label='current', zorder=3)
#     accepted_point = candidates[accepted_idx]
#     ax.scatter([accepted_point[0]], [accepted_point[1]], facecolors='none', edgecolors='black',
#                s=120, marker='s', linewidths=1.8, label='accepted', zorder=4)
#     ax.text(
#         0.02,
#         0.98,
#         f'mean dist: {mean_dist:.3f}\nmean sq dist: {mean_sq_dist:.3f}',
#         transform=ax.transAxes,
#         va='top',
#         ha='left',
#         fontsize=9,
#         bbox=dict(facecolor='white', alpha=0.7, edgecolor='none'),
#     )
#     ax.set_aspect('equal', adjustable='box')
#     ax.set_xlabel('x1')
#     ax.set_ylabel('x2')
#     ax.grid(False)
#     ax.set_title(f'P={P}, rho={rho:.3f}, iter={iter_idx}')


# if not run_mpcn:
#     print('mPCN diagnostics disabled (run_mpcn=False).')
# else:
#     reports_dir.mkdir(parents=True, exist_ok=True)

#     # Ellipse plots: one figure per P, subplots by rho
#     n_rho = len(rho_list)
#     ncols = 3
#     nrows = int(np.ceil(n_rho / ncols))

#     for P in P_list[-1:]:
#         fig, axes = plt.subplots(nrows, ncols, figsize=(4.2 * ncols, 4.0 * nrows), sharex=True, sharey=True)
#         axes = np.array(axes).reshape(-1)
#         for ax, rho in zip(axes, rho_list):
#             snapshot = results['mpcn'][P][rho]['snapshot']
#             if snapshot is None:
#                 ax.text(
#                     0.5,
#                     0.5,
#                     'No snapshot loaded',
#                     transform=ax.transAxes,
#                     ha='center',
#                     va='center',
#                     fontsize=10,
#                 )
#                 ax.set_aspect('equal', adjustable='box')
#                 ax.set_title(f'P={P}, rho={rho:.3f}, iter={plot_iter}')
#                 ax.axis('off')
#                 continue
#             plot_mpcn_snapshot(ax, snapshot, P, rho, plot_iter)
#         for ax in axes[len(rho_list):]:
#             ax.axis('off')
#         fig.suptitle(f'mPCN proposal ellipses (P={P})')
#         fig.tight_layout()
#         fig.savefig(
#             reports_dir / f'03_polar_twist_mpcn_ellipses_P{P}_seed{seed_base}_wx{weight_x_tag}_wy{weight_y_tag}.png',
#             dpi=300,
#             bbox_inches='tight',
#         )
#         plt.show()

# %%
# # Distance summaries vs rho (one curve per P)
# P_sorted = sorted(P_list)
# colors = plt.cm.viridis(np.linspace(0.15, 0.85, len(P_sorted)))
# color_by_P = {P: colors[i] for i, P in enumerate(P_sorted)}

# fig, ax = plt.subplots(figsize=(7, 4))
# for P in P_list:
#     dist_vals = [np.mean(results['mpcn'][P][rho]['mean_dist_samples']) for rho in rho_list]
#     ax.plot(rho_list, dist_vals, marker='o', color=color_by_P[P], label=f'P={P}')
# ax.set_xlabel('rho')
# ax.set_ylabel('Mean distance to center (avg over samples)')
# ax.set_title('Polar twist: mean distance vs rho (mPCN)')
# ax.grid(alpha=0.3)
# ax.legend(loc='best')
# plt.show()

# for P in P_list:
#     fig, ax = plt.subplots(figsize=(8, 4))
#     dist_samples = [results['mpcn'][P][rho]['mean_dist_samples'] for rho in rho_list]
#     ax.boxplot(dist_samples, widths=0.6, showfliers=False)
#     ax.set_xticks(np.arange(1, len(rho_list) + 1))
#     ax.set_xticklabels([f'{rho:.1f}' for rho in rho_list])
#     ax.set_xlabel('rho')
#     ax.set_ylabel('Mean distance to center (per step)')
#     ax.set_title(f'Polar twist: mean distance distribution (P={P})')
#     ax.grid(alpha=0.3, axis='y')
#     plt.show()

# fig, ax = plt.subplots(figsize=(7, 4))
# for P in P_list:
#     dist_vals = [np.mean(results['mpcn'][P][rho]['mean_sq_dist_samples']) for rho in rho_list]
#     ax.plot(rho_list, dist_vals, marker='o', color=color_by_P[P], label=f'P={P}')
# ax.set_xlabel('rho')
# ax.set_ylabel('Mean squared distance to center (avg over samples)')
# ax.set_title('Polar twist: mean squared distance vs rho (mPCN)')
# ax.grid(alpha=0.3)
# ax.legend(loc='best')
# plt.show()

# %%
# # Trace plots: one figure per P, subplots by rho
# rho_list_plot = rho_list[-6:]  # plot only last 6 rhos to avoid overcrowding
# weight_x_tag = str(weight_x).replace('.', 'p')
# weight_y_tag = str(weight_y).replace('.', 'p')

# for method_key, method_label, method_enabled in [
#     ('mpcn', 'mPCN', run_mpcn),
#     ('mtpcn', 'mTPCN', run_mtpcn),
#  ]:
#     if not method_enabled:
#         continue
#     plot_trace_grid(
#         results,
#         P_list=P_list,
#         rho_list_plot=rho_list_plot,
#         burn_in=burn_in,
#         reports_dir=reports_dir,
#         seed_base=seed_base,
#         file_name_fmt=f"03_polar_twist_{method_key}_traces_P{{P}}_last6_seed{{seed_base}}_wx{{weight_x_tag}}_wy{{weight_y_tag}}.png",
#         file_name_kwargs={"weight_x_tag": weight_x_tag, "weight_y_tag": weight_y_tag},
#         max_iters=3000,
#         method_key=method_key,
#         method_label=method_label,
#      )

# %%
# # Histograms: one figure per P, each rho has two subplots (x1, x2)
# bins = 40
# for method_key, method_label, method_enabled in [
#     ('mpcn', 'mPCN', run_mpcn),
#     ('mtpcn', 'mTPCN', run_mtpcn),
#  ]:
#     if not method_enabled:
#         continue
#     for P in P_list[-1:]:
#         fig, axes = plt.subplots(len(rho_list_plot), 2, figsize=(10, 2.6 * len(rho_list_plot)), sharex='col')
#         for row_idx, rho in enumerate(rho_list_plot):
#             chain = results[method_key][P][rho]['chain'][burn_in:]
#             ax1 = axes[row_idx, 0]
#             ax2 = axes[row_idx, 1]
#             ax1.hist(chain[:, 0], bins=bins, density=True, color='#1f77b4', alpha=0.6)
#             ax2.hist(chain[:, 1], bins=bins, density=True, color='#5fa2ce', alpha=0.6)
#             ax1.set_title(f'P={P}, rho={rho:.3f}, x1')
#             ax2.set_title(f'P={P}, rho={rho:.3f}, x2')
#             ax1.grid(alpha=0.3)
#             ax2.grid(alpha=0.3)
#         fig.suptitle(f'{method_label} histograms (P={P})')
#         fig.tight_layout()
#         plt.savefig(
#             reports_dir / f'03_polar_twist_{method_key}_histograms_P{P}_last6_seed{seed_base}_wx{weight_x_tag}_wy{weight_y_tag}.png',
#             dpi=300,
#         )
#         plt.show()

# %%
# ESS/MSJD vs rho curves (one line per P)
weight_x_tag = str(weight_x).replace('.', 'p')
weight_y_tag = str(weight_y).replace('.', 'p')

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    plot_ess_msjd_vs_rho(
        results,
        rho_list=rho_list,
        P_list=P_list,
        reports_dir=reports_dir,
        seed_base=seed_base,
        file_name_fmt=f"polar_twist_{method_key}_ess_msjd_vs_rho_seed{{seed_base}}_wx{{weight_x_tag}}_wy{{weight_y_tag}}.png",
        file_name_kwargs={"weight_x_tag": weight_x_tag, "weight_y_tag": weight_y_tag},
        run_pcn=run_pcn,
        run_mess=run_mess,
        burn_in=burn_in,
        show_mess=False,
        show_pcn=True,
        title_prefix=f"Polar twist ({method_label})",
        normalize_ess=False,
        share_y_metrics=False,
        show_independent=False,
        method_key=method_key,
        method_label=method_label,
     )

# %%
# ESS/MSJD vs rho: compare mPCN vs mTPCN in one figure
apply_pub_style()
from matplotlib.lines import Line2D

weight_x_tag = str(weight_x).replace('.', 'p')
weight_y_tag = str(weight_y).replace('.', 'p')

P_sorted = sorted(P_list)
colors = plt.cm.viridis(np.linspace(0.15, 0.85, len(P_sorted)))
color_by_P = {P: colors[i] for i, P in enumerate(P_sorted)}

method_styles = [
    ('mpcn', 'mPCN', '-', run_mpcn),
    ('mtpcn', 'mTPCN', '--', run_mtpcn),
]

fig, axes = plt.subplots(1, 2, figsize=(12.0, 4.2), sharex=True)
ax_ess, ax_msjd = axes

for P in P_sorted:
    for method_key, method_label, line_style, enabled in method_styles:
        if not enabled:
            continue
        ess_vals = [
            results[method_key][P][rho]['metrics']['ess_mean']
            if rho in results[method_key][P]
            else np.nan
            for rho in rho_list
        ]
        msjd_vals = [
            results[method_key][P][rho]['metrics']['msjd_mean']
            if rho in results[method_key][P]
            else np.nan
            for rho in rho_list
        ]
        ax_ess.plot(
            rho_list,
            ess_vals,
            linestyle=line_style,
            color=color_by_P[P],
            linewidth=2.0,
        )
        ax_msjd.plot(
            rho_list,
            msjd_vals,
            linestyle=line_style,
            color=color_by_P[P],
            linewidth=2.0,
        )

if run_pcn and results.get('pcn'):
    pcn_ess_vals = [
        results['pcn'][rho]['metrics']['ess_mean'] if rho in results['pcn'] else np.nan
        for rho in rho_list
    ]
    pcn_msjd_vals = [
        results['pcn'][rho]['metrics']['msjd_mean'] if rho in results['pcn'] else np.nan
        for rho in rho_list
    ]
    ax_ess.plot(
        rho_list,
        pcn_ess_vals,
        linestyle=':',
        color='black',
        linewidth=2.0,
    )
    ax_msjd.plot(
        rho_list,
        pcn_msjd_vals,
        linestyle=':',
        color='black',
        linewidth=2.0,
    )

ax_ess.set_xlabel(r'$\rho$')
ax_ess.set_ylabel('Effective Sample Size')
ax_ess.grid(alpha=0.25)
ax_msjd.set_xlabel(r'$\rho$')
ax_msjd.set_ylabel('MSJD')
ax_msjd.grid(alpha=0.25)

color_handles = [
    Line2D([0], [0], color=color_by_P[P], linewidth=2, label=f'P={P}')
    for P in P_sorted
 ]
style_handles = [
    Line2D([0], [0], color='gray', linewidth=2, linestyle='-', label='mpCN'),
    Line2D([0], [0], color='gray', linewidth=2, linestyle='--', label='MTpCN'),
    Line2D([0], [0], color='black', linewidth=2, linestyle=':', label='pCN'),
]

fig.legend(
    handles=color_handles,
    loc='center left',
    bbox_to_anchor=(1.02, 0.65),
    frameon=False,
    title='Proposal count',
)
fig.legend(
    handles=style_handles,
    loc='center left',
    bbox_to_anchor=(1.02, 0.3),
    frameon=False,
    title='Algorithm',
)

# fig.suptitle('Polar twist: ESS/MSJD vs $\\rho$ (mpCN vs mtPCN)')
fig.tight_layout()
reports_dir.mkdir(parents=True, exist_ok=True)
fig.savefig(
    reports_dir / (
        'polar_twist_mpcn_mtpcn_ess_msjd_vs_rho_'
        f'seed{seed_base}_wx{weight_x_tag}_wy{weight_y_tag}.png'
    ),
    bbox_inches='tight',
)
plt.show()

# %%
# ESS/MSJD per-parameter vs rho (full range + edges)
for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    plot_ess_msjd_per_param_vs_rho(
        results,
        rho_list=rho_list,
        P_list=P_list,
        reports_dir=reports_dir,
        seed_base=seed_base,
        file_name_fmt=f"polar_twist_{method_key}_ess_msjd_per_param_vs_rho_seed{{seed_base}}_wx{{weight_x_tag}}_wy{{weight_y_tag}}.png",
        file_name_kwargs={"weight_x_tag": weight_x_tag, "weight_y_tag": weight_y_tag},
        run_pcn=run_pcn,
        burn_in=burn_in,
        show_pcn=True,
        title_prefix=f"Polar twist ({method_label})",
        pcn_scale=None,
        normalize_ess=False,
        share_y_metrics=True,
        show_independent=False,
        method_key=method_key,
        method_label=method_label,
     )

# %%
# Rejection rate vs rho (one line per P)
for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    plot_rejection_vs_rho(
        results,
        rho_list=rho_list,
        P_list=P_list,
        reports_dir=reports_dir,
        seed_base=seed_base,
        file_name_fmt=f"polar_twist_{method_key}_rejection_vs_rho_seed{{seed_base}}_wx{{weight_x_tag}}_wy{{weight_y_tag}}.png",
        file_name_kwargs={"weight_x_tag": weight_x_tag, "weight_y_tag": weight_y_tag},
        run_pcn=run_pcn,
        show_pcn=True,
        title_prefix=f"Polar twist ({method_label})",
        method_key=method_key,
        method_label=method_label,
     )

# %%
# ESS/MSJD tables (rows=P, columns=rho + pCN)
col_labels = [f'rho={rho:.3f}' for rho in rho_list]

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    ess_rows = []
    msjd_rows = []
    row_labels = []

    for P in P_list:
        ess_row = [results[method_key][P][rho]['metrics']['ess_mean'] for rho in rho_list]
        msjd_row = [results[method_key][P][rho]['metrics']['msjd_mean'] for rho in rho_list]
        ess_rows.append(ess_row)
        msjd_rows.append(msjd_row)
        row_labels.append(f'P={P}')

    if run_pcn and results['pcn']:
        ess_row = [results['pcn'][rho]['metrics']['ess_mean'] for rho in rho_list]
        msjd_row = [results['pcn'][rho]['metrics']['msjd_mean'] for rho in rho_list]
        ess_rows.append(ess_row)
        msjd_rows.append(msjd_row)
        row_labels.append('pCN')

    ess_table = pd.DataFrame(ess_rows, index=row_labels, columns=col_labels)
    msjd_table = pd.DataFrame(msjd_rows, index=row_labels, columns=col_labels)

    ess_table_display = ess_table.round(0).astype(int)
    msjd_table_display = msjd_table.round(3)
    print(f'ESS table ({method_label} across rho; pCN row if enabled):')
    display(ess_table_display)
    print(f'MSJD table ({method_label} across rho; pCN row if enabled):')
    display(msjd_table_display)

# %% [markdown]
# ## Analyzing mixing for extreme $\rho$

# %%
# Run extra rho chains for the edge ranges
rho_low = np.round(np.arange(0.0, 0.1001, 0.005), 5)
rho_high = np.round(np.arange(0.85, 1.0001, 0.005), 5)
rho_edges = np.unique(np.concatenate([rho_low, rho_high]))

def ensure_method_rho_results(method_key, method_label, rho_values, use_diag=False):
    missing_edges = []
    for P in P_list:
        results[method_key].setdefault(P, {})
        for rho in rho_values:
            rho_key = float(rho)
            if rho_key in results[method_key][P]:
                continue
            samples_path, metrics_path = chain_cache_paths(
                method_key, rho=rho_key, seed_base=seed_base, P=P
            )
            loaded = load_chain_bundle(samples_path, metrics_path)
            if loaded is None:
                missing_edges.append((method_key, P, rho_key))
                continue
            chain, accept_rate, runtime_sec, metrics = loaded
            if metrics is None or 'ess_per_param' not in metrics:
                metrics = summarize_chain_metrics(
                    chain, runtime_sec, burn_in=burn_in, max_lag=max_lag
                )
                save_metrics_json(metrics_path, metrics, accept_rate, runtime_sec)
            entry = {
                'chain': chain,
                'runtime_sec': runtime_sec,
                'accept_rate': accept_rate,
                'metrics': metrics,
            }
            if use_diag:
                diag_path = mpcn_diag_path(P, rho_key, seed_base)
                snapshot, mean_dist_samples, mean_sq_dist_samples = load_mpcn_diagnostics(diag_path)
                entry.update({
                    'snapshot': snapshot,
                    'mean_dist_samples': np.asarray(mean_dist_samples, dtype=float),
                    'mean_sq_dist_samples': np.asarray(mean_sq_dist_samples, dtype=float),
                })
            results[method_key][P][rho_key] = entry
            accept_display = np.nan if accept_rate is None else accept_rate
            print(
                f'{method_label} edge rho loaded: P={P}, rho={rho_key:.3f}, '
                f'accept={accept_display:.3f}, runtime={runtime_sec:.2f}s'
            )
    return missing_edges

missing_edges = []
if run_mpcn:
    missing_edges += ensure_method_rho_results('mpcn', 'mPCN', rho_edges, use_diag=True)
if run_mtpcn:
    missing_edges += ensure_method_rho_results('mtpcn', 'mTPCN', rho_edges, use_diag=False)
if missing_edges:
    preview = "\n".join([f"{method} P={P}, rho={rho:.3f}" for method, P, rho in missing_edges[:10]])
    job_dir = repo_root / "jobs" / "polar_twist" / f"{run_id}_{data_id}"
    raise RuntimeError(
        "Missing edge-rho chains. Run the job script to generate chains, then re-run this cell.\n"
        f"Job dir: {job_dir}\n"
        f"Example: bash {job_dir / 'launch_workers.sh'}\n"
        f"Missing ({len(missing_edges)}):\n{preview}"
    )

# %%
# Zoomed-in rho ranges (0-0.1 and 0.9-1.0)
apply_pub_style()

rho_low = np.round(np.arange(0.0, 0.1001, 0.005), 5)
rho_high = np.round(np.arange(0.85, 1.0001, 0.005), 5)

P_sorted = sorted(P_list)
colors = plt.cm.viridis(np.linspace(0.15, 0.85, len(P_sorted)))
color_by_P = {P: colors[i] for i, P in enumerate(P_sorted)}

def get_metric_for_rho(results_dict, P, rho, metric_key):
    entry = results_dict.get(P, {}).get(float(rho))
    if entry is None:
        return np.nan
    return entry['metrics'][metric_key]

reports_dir.mkdir(parents=True, exist_ok=True)

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    fig, axes = plt.subplots(1, 2, figsize=(12.0, 4.2), sharey=True)
    ax_low, ax_high = axes

    for P in P_sorted:
        ess_low = [get_metric_for_rho(results[method_key], P, rho, 'ess_mean') for rho in rho_low]
        ess_high = [get_metric_for_rho(results[method_key], P, rho, 'ess_mean') for rho in rho_high]
        ax_low.plot(rho_low, ess_low, marker='o', color=color_by_P[P], label=f'P={P}')
        ax_high.plot(rho_high, ess_high, marker='o', color=color_by_P[P], label=f'P={P}')

    ax_low.set_title(r'ESS vs $\rho$ (0.0-0.1)')
    ax_low.set_xlabel(r'$\rho$')
    ax_low.set_ylabel('Effective Sample Size')
    ax_low.grid(alpha=0.25)

    ax_high.set_title(r'ESS vs $\rho$ (0.9-1.0)')
    ax_high.set_xlabel(r'$\rho$')
    ax_high.grid(alpha=0.25)

    handles, labels = ax_low.get_legend_handles_labels()
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1.02, 0.5), frameon=False)
    fig.suptitle(fr'Polar twist ({method_label}): ESS at $\rho$ range edges')
    fig.tight_layout()

    filename = (
        f'polar_twist_{method_key}_ess_rho_edges_0.00-0.10_0.85-1.00_seed{seed_base}_'
        f'wx{weight_x_tag}_wy{weight_y_tag}.png'
     )
    fig.savefig(reports_dir / filename, bbox_inches='tight')
    plt.show()

# %%
# Zoomed-in MSJD vs rho (0-0.1 and 0.9-1.0)
apply_pub_style()

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    fig, axes = plt.subplots(1, 2, figsize=(12.0, 4.2), sharey=True)
    ax_low, ax_high = axes

    for P in P_sorted:
        msjd_low = [get_metric_for_rho(results[method_key], P, rho, 'msjd_mean') for rho in rho_low]
        msjd_high = [get_metric_for_rho(results[method_key], P, rho, 'msjd_mean') for rho in rho_high]
        ax_low.plot(rho_low, msjd_low, marker='o', color=color_by_P[P], label=f'P={P}')
        ax_high.plot(rho_high, msjd_high, marker='o', color=color_by_P[P], label=f'P={P}')

    ax_low.set_title(r'MSJD vs $\rho$ (0.0-0.1)')
    ax_low.set_xlabel(r'$\rho$')
    ax_low.set_ylabel('MSJD')
    ax_low.grid(alpha=0.25)

    ax_high.set_title(r'MSJD vs $\rho$ (0.9-1.0)')
    ax_high.set_xlabel(r'$\rho$')
    ax_high.grid(alpha=0.25)

    handles, labels = ax_low.get_legend_handles_labels()
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1.02, 0.5), frameon=False)
    fig.suptitle(fr'Polar twist ({method_label}): MSJD at $\rho$ range edges')
    fig.tight_layout()

    filename = (
        f'polar_twist_{method_key}_msjd_rho_edges_0.00-0.10_0.85-1.00_seed{seed_base}_'
        f'wx{weight_x_tag}_wy{weight_y_tag}.png'
     )
    fig.savefig(reports_dir / filename, bbox_inches='tight')
    plt.show()

# %%
# Edge rho ranges combined
rho_low = np.round(np.arange(0.0, 0.1001, 0.005), 5)
rho_high = np.round(np.arange(0.85, 1.0001, 0.005), 5)
rho_edges = np.unique(np.concatenate([rho_low, rho_high]))
rho_edges = rho_high

def get_param_metric(results_dict, P, rho, metric_key, param_index):
    entry = results_dict.get(P, {}).get(float(rho))
    if entry is None:
        return np.nan
    values = entry['metrics'].get(metric_key)
    if values is None or len(values) <= param_index:
        return np.nan
    return values[param_index]

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    fig, axes = plt.subplots(2, 2, figsize=(12.0, 7.0), sharex=True)
    for P in P_sorted:
        ess_x1 = [get_param_metric(results[method_key], P, rho, 'ess_per_param', 0) for rho in rho_edges]
        ess_x2 = [get_param_metric(results[method_key], P, rho, 'ess_per_param', 1) for rho in rho_edges]
        msjd_x1 = [get_param_metric(results[method_key], P, rho, 'msjd_per_param', 0) for rho in rho_edges]
        msjd_x2 = [get_param_metric(results[method_key], P, rho, 'msjd_per_param', 1) for rho in rho_edges]
        axes[0, 0].plot(rho_edges, ess_x1, marker='o', color=color_by_P[P], label=f'{method_label} P={P}')
        axes[1, 0].plot(rho_edges, ess_x2, marker='o', color=color_by_P[P])
        axes[0, 1].plot(rho_edges, msjd_x1, marker='o', color=color_by_P[P])
        axes[1, 1].plot(rho_edges, msjd_x2, marker='o', color=color_by_P[P])

    axes[0, 0].set_title('ESS (x1) edges')
    axes[0, 1].set_title('MSJD (x1) edges')
    axes[1, 0].set_title('ESS (x2) edges')
    axes[1, 1].set_title('MSJD (x2) edges')
    for ax in axes[1, :]:
        ax.set_xlabel(r'$\rho$')
    axes[0, 0].set_ylabel('ESS')
    axes[1, 0].set_ylabel('ESS')
    axes[0, 1].set_ylabel('MSJD')
    axes[1, 1].set_ylabel('MSJD')
    for ax in axes.ravel():
        ax.grid(alpha=0.25)

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1.02, 0.5), frameon=False)
    fig.suptitle(fr'Polar twist ({method_label}): ESS/MSJD per-parameter at $\rho$ edges')
    fig.tight_layout()
    fig.savefig(
        reports_dir / f'polar_twist_{method_key}_ess_msjd_per_param_rho_edges_0.85-1.00_seed{seed_base}_wx{weight_x_tag}_wy{weight_y_tag}.png',
        bbox_inches='tight',
    )
    plt.show()

# %%
# Rejection rate vs rho (edge ranges)
apply_pub_style()

rho_low = np.round(np.arange(0.0, 0.1001, 0.005), 5)
rho_high = np.round(np.arange(0.85, 1.0001, 0.005), 5)

P_sorted = sorted(P_list)
colors = plt.cm.viridis(np.linspace(0.15, 0.85, len(P_sorted)))
color_by_P = {P: colors[i] for i, P in enumerate(P_sorted)}

def get_reject_rate(results_dict, P, rho):
    entry = results_dict.get(P, {}).get(float(rho))
    if entry is None:
        return np.nan
    accept_rate = entry.get('accept_rate')
    if accept_rate is None:
        return np.nan
    return 1.0 - accept_rate

reports_dir.mkdir(parents=True, exist_ok=True)

for method_key, method_label, method_enabled in [
    ('mpcn', 'mPCN', run_mpcn),
    ('mtpcn', 'mTPCN', run_mtpcn),
 ]:
    if not method_enabled:
        continue
    fig, axes = plt.subplots(1, 2, figsize=(12.0, 4.2), sharey=True)
    ax_low, ax_high = axes

    for P in P_sorted:
        reject_low = [get_reject_rate(results[method_key], P, rho) for rho in rho_low]
        reject_high = [get_reject_rate(results[method_key], P, rho) for rho in rho_high]
        ax_low.plot(rho_low, reject_low, marker='o', color=color_by_P[P], label=f'P={P}')
        ax_high.plot(rho_high, reject_high, marker='o', color=color_by_P[P], label=f'P={P}')

    ax_low.set_title(r'Rejection rate vs $\rho$ (0.0-0.1)')
    ax_low.set_xlabel(r'$\rho$')
    ax_low.set_ylabel('Rejection rate')
    ax_low.grid(alpha=0.25)

    ax_high.set_title(r'Rejection rate vs $\rho$ (0.9-1.0)')
    ax_high.set_xlabel(r'$\rho$')
    ax_high.grid(alpha=0.25)

    handles, labels = ax_low.get_legend_handles_labels()
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1.02, 0.5), frameon=False)
    fig.suptitle(fr'Polar twist ({method_label}): rejection rate at $\rho$ range edges')
    fig.tight_layout()

    filename = (
        f'polar_twist_{method_key}_rejection_rho_edges_0.00-0.10_0.85-1.00_seed{seed_base}_'
        f'wx{weight_x_tag}_wy{weight_y_tag}.png'
     )
    fig.savefig(reports_dir / filename, bbox_inches='tight')
    plt.show()
